# %% [markdown]
# # 모듈(Module)과 Import
#
# ## 1. 모듈이란?
#
# **모듈(Module)** 은 함수, 변수, 클래스 등을 담고 있는 파이썬 파일(.py)입니다.
#
# ### 왜 모듈을 사용할까요?
# - 코드를 **재사용**할 수 있습니다
# - 코드를 **체계적으로 관리**할 수 있습니다
# - 여러 프로젝트에서 **같은 기능을 공유**할 수 있습니다
#
# ### 예시
# 계산기 기능을 매번 새로 작성하는 대신, 한 번 만들어서 여러 곳에서 가져다 쓸 수 있습니다!

# %% [markdown]
# ## 2. 우리가 만든 계산기 모듈 살펴보기
#
# `module/cal.py` 파일에는 다음과 같은 함수들이 있습니다:
#
# ```python
# def add(a, b):        # 더하기
# def subtract(a, b):   # 빼기
# def multiply(a, b):   # 곱하기
# def divide(a, b):     # 나누기
# ```
#
# 이 함수들을 다른 파일에서 가져다 쓸 수 있습니다!

# %% [markdown]
# ## 3. Import 기본 사용법
#
# ### 방법 1: 전체 모듈 가져오기

# %%
# module 폴더의 cal.py를 가져옵니다
import module.cal

# 모듈명.함수명() 형태로 사용
result = module.cal.add(10, 5)
print(f"10 + 5 = {result}")

result = module.cal.subtract(10, 5)
print(f"10 - 5 = {result}")
# Out:
# 10 + 5 = 15
# 10 - 5 = 5

# %% [markdown]
# ### 방법 2: 모듈에 별명 붙이기 (as)

# %%
# 긴 이름을 짧게 줄일 수 있습니다
import module.cal as calc

# 이제 calc로 간단하게 사용 가능
result = calc.multiply(7, 3)
print(f"7 × 3 = {result}")

result = calc.divide(20, 4)
print(f"20 ÷ 4 = {result}")

# %% [markdown]
# ### 방법 3: 특정 함수만 가져오기 (from ... import)

# %%
# 필요한 함수만 선택해서 가져오기
from module.cal import add, multiply

# 모듈명 없이 바로 함수 사용 가능!
print(f"15 + 25 = {add(15, 25)}")
print(f"6 × 7 = {multiply(6, 7)}")

# %% [markdown]
# ### 방법 4: 모든 함수 가져오기

# %%
# * (별표)는 '모든 것'을 의미합니다
from module.cal import *

# 모든 함수를 바로 사용 가능
print(f"100 + 50 = {add(100, 50)}")
print(f"100 - 50 = {subtract(100, 50)}")
print(f"100 × 50 = {multiply(100, 50)}")
print(f"100 ÷ 50 = {divide(100, 50)}")

# %% [markdown]
# ## 8. 도전 과제 🚀
#
# ### 나만의 모듈 만들기
#
# 1. `mymodule.py` 파일을 만들고
# 2. 다음 함수들을 작성해보세요:
#    - `square(x)`: 제곱을 구하는 함수
#    - `cube(x)`: 세제곱을 구하는 함수
#    - `power(x, n)`: x의 n제곱을 구하는 함수
# 3. 이 모듈을 import해서 사용해보세요!
#
# 힌트: cal.py를 참고하세요!, 아래 코드가 정상 실행되도록 만드세요!

# %%
import mymodule

print(mymodule.square(7))      # 49
print(mymodule.cube(4))        # 64
print(mymodule.power(3, 4))    # 81

# 또는
from mymodule import square, cube

print(square(10))   # 100
print(cube(5))      # 125
