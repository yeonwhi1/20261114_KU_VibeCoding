# %% [markdown]
# ### 다음 조건에 맞게 boolean값이 나오도록 작성해보세요.
#
# ```python
#
# # 1. 이름이 다람쥐이면 True
#
# # 2. 성인이면 True (19세 이상을 성인이라고 기준함)
#
# # 3. 성인이면서 여성이면 True
#
# # 4. 이름이 다람쥐가 아니면 True (논리연산 not 이용)
# ```

# %%
name = '곰'
age = 20
gender = 'male'

# %%
# 1번 예시
print(name == '다람쥐')
